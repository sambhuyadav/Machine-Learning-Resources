# %% [markdown]
# <a href="https://colab.research.google.com/github/sambhuyadav/Machine-Learning-Resources/blob/main/Correlations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libaries
#this is necessary for ALL code blocks below

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats

# %% [markdown]
# #Penguin Data

# %%
penguins = sns.load_dataset("penguins")

penguins = penguins.dropna()

penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# ## Weight vs Wingspan

# %%
#Is there a relation b/w body_mass_g vs flipper_length_mm

plt.title("Weight vs Wingspan")

sns.scatterplot(data=penguins, x='body_mass_g', y='flipper_length_mm')

plt.show()

# %%
#rho value

#Is there a relation b/w body_mass_g vs flipper_length_mm


#For Pearsonr test
#Ho: There is NO correlation between X and Y
#Ha: There is a correlation between X and Y

from scipy import stats

stats.pearsonr(x = penguins['body_mass_g'], y = penguins['flipper_length_mm'])
# Out:
# PearsonRResult(statistic=0.8729788985653614, pvalue=3.13283625097126e-105)

# %% [markdown]
# ##Bill Depth and Flipper Length

# %%
#Is there a relation b/w bill_depth_mm vs flipper_length_mm

plt.title("Bill Depth vs Flipper Length")

sns.scatterplot(data=penguins, x='bill_depth_mm', y='flipper_length_mm')

plt.show()

# %%
#Pearson's rho value for the above plot

stats.pearsonr(x = penguins['bill_depth_mm'], y = penguins['flipper_length_mm'])
# Out:
# PearsonRResult(statistic=-0.5777916963366727, pvalue=4.778176856112898e-31)

# %%
#colour coding the above plot using hue='species'

plt.title("Bill Depth vs Flipper Length")

sns.scatterplot(data=penguins, x='bill_depth_mm', y='flipper_length_mm', hue='species')

plt.show()

# %% [markdown]
# ## Weight vs Bill Length

# %%
#Scatter plot

#Is there a relation b/w body_mass_g vs bill_length_mm

plt.title("Weight vs Bill_length")
sns.scatterplot(data = penguins, x = 'body_mass_g', y = 'bill_length_mm')
plt.show()

# %%
#Pearson's rho value for above

stats.pearsonr(x = penguins['body_mass_g'] , y = penguins['bill_length_mm'])
# Out:
# PearsonRResult(statistic=0.5894511101769491, pvalue=1.53861351448595e-32)

# %%
#Split the above scatter plot by hue='species'


plt.title("Weight vs Bill_length")
sns.scatterplot(data = penguins, x = 'body_mass_g', y = 'bill_length_mm', hue='species')
plt.show()

# %% [markdown]
# ## Weight vs Weight

# %%
#Is there a relation b/w body_mass_g vs body_mass_g

plt.title("Weight vs Weight")
sns.scatterplot(data = penguins, x = 'body_mass_g', y = 'body_mass_g')
plt.show()

# %%
#pearson's correl b/w wt and wt


#For Pearsonr test
#Ho: There is NO correlation between X and Y
#Ha: There is a correlation between X and Y

# %%
#spearman's correl b/w wt and wt


#For spearmanr test
#Ho: There is NO "monotonic" correlation between X and Y
#Ha: There is a "monotonic" correlation between X and Y

# %% [markdown]
# ## Length of Beak vs Depth of Beak

# %%
#Is there a relation b/w bill_length_mm vs bill_depth_mm

plt.title("Length of beak  vs Depth of beak")
sns.scatterplot(data = penguins, x = 'bill_length_mm', y = 'bill_depth_mm')
plt.show()

# %%
#Is there a relation b/w bill_length_mm vs bill_depth_mm
#Pearsonr


#Ho: there is NO correlation between the variables
#Ha: there is a correlation between the variables

# %% [markdown]
# #Custom generated monotonic data

# %%
#Positive monotonic function

x_1 = np.arange(1,5,0.5)
y_1 = x_1**2

x_2 = np.arange(5,15,0.5)
#y_2 = np.full(shape=x_2.shape, fill_value=25).astype('int')
y_2 = y_1[-1]+(x_2-5)/1000

x_3 = np.arange(15,20,0.5)
y_3 = y_2[-1]+(x_3-15)*4

x_vals = np.concatenate([x_1,x_2,x_3])
y_vals = np.concatenate([y_1,y_2,y_3])

plt.xlabel("x_vals")
plt.ylabel("y_vals")

pearson_rho = stats.pearsonr(x_vals, y_vals)[0]
spearman_rho = stats.spearmanr(x_vals, y_vals)[0]
plt.title(f"pearson_rho = {pearson_rho : .2f} and spearman_rho = {spearman_rho : .2f}")


plt.grid(axis="y")
sns.scatterplot(x=x_vals,y=y_vals)
plt.show()

# %%
stats.pearsonr(x_vals, y_vals)[0]
# Out:
# 0.8592543557795874

# %%
stats.spearmanr(x_vals, y_vals)[0]
# Out:
# 0.9998905728507966

# %%
#Negative monotonic function


x_vals = np.arange(1,10,0.2)
w_vals = x_vals**5
y_vals = max(w_vals) - w_vals

plt.xlabel("x_vals")
plt.ylabel("y_vals")
pearson_rho = stats.pearsonr(x_vals, y_vals)[0]
spearman_rho = stats.spearmanr(x_vals, y_vals)[0]
plt.title(f"pearson_rho = {pearson_rho : .2f} and spearman_rho = {spearman_rho : .2f}")
plt.grid(axis="y")
sns.scatterplot(x=x_vals,y=y_vals)
plt.show()

# %% [markdown]
# #Quizzes

# %%
#Q2

"""
Given two arrays X and Y. Find Spearman’s Rank Correlation
x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]
"""

x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]

stats.spearmanr(x, y)
# Out:
# SignificanceResult(statistic=-0.9999999999999999, pvalue=1.4042654220543672e-24)

# %%
#Quiz 3

"""
Given two arrays X and Y. Find Pearson correlation coefficient
x = [1, 2, 3, 4, 5, 6, 7]
y = [10, 9, 2.5, 6, 4, 3, 2]
"""

x = [1, 2, 3, 4, 5, 6, 7]
y = [10, 9, 2.5, 6, 4, 3, 2]

stats.pearsonr(x, y)
# Out:
# PearsonRResult(statistic=-0.8285038835884277, pvalue=0.021280260007523352)

# %% [markdown]
# #Heatmaps

# %%
#Correlation Table

penguin_continous_RVs = penguins[['bill_length_mm', 'bill_depth_mm',
                           'flipper_length_mm', 'body_mass_g']]

print("Correlations between Categorical RVs of penguins dataset:\n\n\n")
penguin_continous_RVs.corr()
# Out:
# Correlations between Categorical RVs of penguins dataset:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
#
#                    body_mass_g
# bill_length_mm        0.589451
# bill_depth_mm        -0.472016
# flipper_length_mm     0.872979
# body_mass_g           1.000000

# %%
#Heatmap of Correlation Table

plt.title("Heatmap of Correlations between Categorical RVs of penguins dataset\n")
plt.xticks(rotation=45)
sns.heatmap(data=penguin_continous_RVs.corr(), annot=True)
plt.show()
